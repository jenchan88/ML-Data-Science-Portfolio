# %%
import pandas as pd

walking = pd.read_csv("data_test1_20cyclic_1314N.csv")

walking #walking
# Out:
#      Time (s)  F0 (V)  F1 (V)  F2 (V)  F3 (V)  F4 (V)  F5 (V)  F6 (V)  F7 (V)
# 0        2.34    0.58    0.59    0.58    0.59    0.58    0.59    0.58    0.59
# 1        2.97    0.58    0.59    0.59    0.58    0.58    0.59    0.58    0.58
# 2        3.59    0.58    0.58    0.58    0.59    0.58    0.59    0.58    0.58
# 3        4.22    0.58    0.58    0.58    0.59    0.58    0.59    0.58    0.58
# 4        4.84    0.58    0.58    0.58    0.58    0.58    0.59    0.58    0.58
# ..        ...     ...     ...     ...     ...     ...     ...     ...     ...
# 352    222.34    0.58    0.59    0.59    0.58    0.58    0.58    0.58    0.58
# 353    222.97    0.58    0.59    0.59    0.58    0.58    0.58    0.58    0.59
# 354    223.59    0.58    0.59    0.59    0.58    0.58    0.59    0.58    0.59
# 355    224.22    0.58    0.59    0.59    0.58    0.58    0.59    0.58    0.58
# 356    224.84    0.58    0.59    0.59    0.58    0.58    0.58    0.58    0.58
#
# [357 rows x 9 columns]

# %%
standing = pd.read_csv("data_test2_standing_525N.csv")

standing
# Out:
#     Time (s)  F0 (V)  F1 (V)  F2 (V)  F3 (V)  F4 (V)  F5 (V)  F6 (V)  F7 (V)
# 0       2.34    0.59    0.59    0.59    0.59    0.59    0.59    0.58    0.59
# 1       2.96    0.59    0.59    0.59    0.59    0.58    0.59    0.58    0.59
# 2       3.59    0.59    0.59    0.59    0.59    0.58    0.59    0.58    0.59
# 3       4.21    0.59    0.59    0.59    0.59    0.59    0.59    0.58    0.59
# 4       4.84    0.59    0.59    0.59    0.59    0.59    0.59    0.58    0.59
# ..       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 87     56.72    0.59    0.59    0.59    0.59    0.58    0.59    0.58    0.59
# 88     57.34    0.58    0.59    0.59    0.59    0.59    0.59    0.58    0.59
# 89     57.97    0.58    0.59    0.59    0.59    0.59    0.59    0.58    0.59
# 90     58.59    0.58    0.59    0.59    0.59    0.59    0.59    0.58    0.59
# 91     59.22    0.59    0.59    0.60    0.58    0.58    0.59    0.58    0.59
#
# [92 rows x 9 columns]

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Load the entire dataset
walking_df = pd.read_csv("data_test1_20cyclic_1314N.csv")

# Define the global minimum and maximum values
global_min = 0.33
global_max = 3.3

# Extract the range of rows to be scaled
walking_range = walking_df.iloc[75:85, 1:]

# Manually scale the data using the global minimum and maximum values
walking_scaled_data = (walking_range - global_min) / (global_max - global_min)

# Convert the scaled data back to a dataframe
walking_scaled_df = pd.DataFrame(walking_scaled_data, columns=walking_range.columns)

# Display the scaled dataframe
walking_scaled_df
# Out:
#       F0 (V)    F1 (V)    F2 (V)    F3 (V)    F4 (V)    F5 (V)    F6 (V)  \
# 75  0.084175  0.087542  0.090909  0.087542  0.087542  0.087542  0.084175
# 76  0.087542  0.090909  0.090909  0.090909  0.097643  0.087542  0.087542
# 77  0.087542  0.094276  0.101010  0.107744  0.127946  0.101010  0.097643
# 78  0.101010  0.107744  0.134680  0.175084  0.205387  0.141414  0.158249
# 79  0.151515  0.148148  0.171717  0.242424  0.249158  0.158249  0.164983
# 80  0.148148  0.144781  0.171717  0.242424  0.252525  0.158249  0.168350
# 81  0.148148  0.141414  0.171717  0.239057  0.249158  0.158249  0.161616
# 82  0.151515  0.138047  0.151515  0.181818  0.175084  0.114478  0.104377
# 83  0.097643  0.094276  0.101010  0.101010  0.111111  0.094276  0.087542
# 84  0.087542  0.087542  0.090909  0.087542  0.087542  0.087542  0.087542
#
#       F7 (V)
# 75  0.087542
# 76  0.087542
# 77  0.104377
# 78  0.168350
# 79  0.168350
# 80  0.168350
# 81  0.168350
# 82  0.104377
# 83  0.090909
# 84  0.087542

# %%
global_min
global_max
# Out:
# 3.3

# %%
standing_df = pd.read_csv("data_test2_standing_525N.csv")
standing_range = standing_df.iloc[36:73, 1:]  # Exclude the first column

# Fit and transform the data
standing_scaled_data = scaler.fit_transform(standing_range)

# Convert the scaled data back to a dataframe
standing_scaled_df = pd.DataFrame(standing_scaled_data, columns=standing_range.columns)

# Display the scaled dataframe
standing_scaled_df
# Out:
#     F0 (V)    F1 (V)    F2 (V)    F3 (V)    F4 (V)  F5 (V)    F6 (V)    F7 (V)
# 0      0.0  0.000000  0.000000  0.000000  0.000000    0.00  0.000000  0.000000
# 1      0.0  0.000000  0.142857  0.000000  0.090909    0.00  0.000000  0.333333
# 2      0.0  0.333333  0.428571  0.500000  0.636364    0.50  0.333333  1.000000
# 3      0.5  0.666667  0.714286  0.833333  0.909091    0.50  0.666667  1.000000
# 4      0.5  0.666667  0.857143  0.833333  0.909091    0.50  0.666667  1.000000
# 5      0.5  1.000000  0.714286  0.833333  0.909091    0.50  0.666667  1.000000
# 6      1.0  0.666667  0.714286  0.833333  0.818182    1.00  0.666667  0.666667
# 7      0.5  0.666667  0.714286  0.833333  0.909091    0.75  0.666667  1.000000
# 8      1.0  0.666667  0.714286  1.000000  0.909091    0.75  0.666667  1.000000
# 9      1.0  0.666667  0.857143  0.833333  1.000000    0.75  0.666667  0.666667
# 10     1.0  1.000000  0.714286  0.833333  0.909091    0.75  0.666667  1.000000
# ...

# %%
import numpy as np

def create_images(dataframe):
    images = []
    for _, row in dataframe.iterrows():
        # 3x5 grid for each image representing the sensor layout
        image = np.zeros((3, 5))

        image[0, 0] = row['F5 (V)']  # first sensor
        image[0, 2] = row['F0 (V)']
        image[0, 4] = row['F1 (V)']
        image[1, 1] = row['F6 (V)']
        image[1, 3] = row['F7 (V)']
        image[2, 0] = row['F4 (V)']
        image[2, 2] = row['F3 (V)']
        image[2, 4] = row['F2 (V)']

        images.append(image)

    return images

walking_images = create_images(walking_scaled_df)
#standing_images = create_images(standing_scaled_df)

# %%
import matplotlib.pyplot as plt

plt.imshow(walking_images[6], cmap='gray')
plt.title('Walking Image (end)')
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.imshow(standing_images[27], cmap='gray')
plt.title('Standing Image')
plt.axis('off')
plt.show()

# take 3 or 4 key iamges of the curve (start, middle, peak, middle, end)
